# %% [markdown]
# # Practice work 4

# %%
import pandas as pd
# anime.csv file which is imported
url = "/Users/User/Desktop/Practice4/anime.csv"  #write path of anime.csv file in your device

# %% [markdown]
# 1) Read the .csv file and store it as a pandas Data Frame (0.1 p)

# %%
#your code

# %% [markdown]
# 2) Create new Data Frame which called 'df_anime' that contains only first 8 columns and first 200 rows (0.2 p)

# %%
#your code

# %% [markdown]
# 3) Delete NULL values from columns 'startYr', 'finishYr', 'mediaType', 'eps', 'duration' (0.2 p)

# %%
#your code

# %% [markdown]
# 4) Show all anime which are media type are not 'Movie' (0.2 p)

# %%
#your code

# %% [markdown]
# 5) Show all anime which contain several episodes (0.2 p)

# %%
#your code

# %% [markdown]
# ## Matplotlib

# %%
import pandas as pd
# day.csv file which is imported
file = "/Users/User/Desktop/Practice4/day.csv"  #write path of day.csv file in your device

# %% [markdown]
# 6) Read the .csv file and store it as a pandas Data Frame (0.1 p)

# %%
#your code

# %% [markdown]
# 7) Task. (7 points)
# Re-create the subplots below using:
# - Variables: temp, cnt, season;
# - Figsize = (10, 8);
# - Title customization(hint: use fig.suptitle()): size is 14, weight is bold, position is (0.5,1.01);
# - x and y label customization: size is 12, weight is bold. Hint: use position=(0,-0.1) and position=(-0.1,0) to place the label into correct places;
# - With grid;
# - Use other customization based on the subplots below.

# %%
#Don't run this line
# Out:
# <PIL.Image.Image image mode=RGBA size=600x600 at 0x200A26CEF70>

# %%
#your code
