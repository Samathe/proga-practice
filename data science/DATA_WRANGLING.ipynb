# %% [markdown]
# ### **Week 6**
# ## **Data wrangling**

# %% [markdown]
# ---
# ### <font color='3E5C76'>Table of contents<font><a class='anchor' id='top'></a>
#
# 1. [Data Wrangling in Data Science](#scrollTo=Ofkxpc--MZfA&uniqifier=1)
# 2. [Data Cleaning — Handling Missing Data](#scrollTo=MKUMZ9zrAL_G&uniqifier=1)
# 3. [Imputation Techniques](#scrollTo=w7qdOU5vBc5Z&uniqifier=1)
# 4. [Handling outliers](#scrollTo=4HAVLrKuCse_&uniqifier=1)
# 5. [ Z-Score Method](#scrollTo=9J9E6wSNDsFa&uniqifier=1)
# 6. [Feature Scaling in Machine Learning](#scrollTo=0Dk88FNqEHOh&uniqifier=1)
# 7. [Normalization (Min-Max Scaling)](#scrollTo=x2KfM8bWF7K0&uniqifier=1)
# 8. [Encoding Categorical Variables](#scrollTo=jiHREydyHIV2&uniqifier=1)
# 9. [Feature Extraction](#scrollTo=kXB8xr2_Hztc&uniqifier=1)
# 10. [Feature Selection ](#scrollTo=F_cLLIr7JhqD&uniqifier=1)
# 11. [Log & Power Transformations](#scrollTo=ZPTCNGidKXIP&uniqifier=1)
# 12. [Data Aggregation & Grouping](#scrollTo=TzeqPNbzKEBt&uniqifier=1)
# 13. [Summary & Best Practices](scrollTo=HYCkmbjgLKnd&uniqifier=1)
# ---

# %% [markdown]
# # <center><font color='#000000'>📊 1.Data Wrangling in Data Science</font></center>
#
# ---
#
# ## <font color='##000000'>💡 What is Data Wrangling?</font>
#
# **Data Wrangling** is the process of transforming raw, messy data into a clean and structured format, making it suitable for analysis and machine learning. It ensures data quality, consistency, and usability.
#
# > 🧹 **"Think of Data Wrangling as cleaning your workspace before starting a big project — organized data leads to better results."**
#
# ---
#
# ## <font color='#000000'>✨ Why is Data Wrangling Important?</font>
#
# <img src="https://cdn-icons-png.flaticon.com/512/3191/3191808.png" alt="data cleaning" width="120" align="right"/>
#
# - **Raw data** is often incomplete, inconsistent, and full of errors.
# - Machine learning models and data analysis rely on high-quality, structured data.
# - **💯 Clean Data → 📈 Accurate Analysis → 🧠 Better Decisions**
#
# > ⚡ **Data Scientists spend ~80% of their time wrangling data before actual analysis.**
#
# ---
#
# ## <font color='#000000'>📁 What is Raw Data?</font>
#
# Raw data is unprocessed information collected from sources like **surveys**, **databases**, **APIs**, or **sensors**. It usually contains:
#
# ✅ Missing values
# ✅ Duplicates
# ✅ Inconsistent formats
# ✅ Outliers
#
#
# **Example of Raw Data:**
#
# ```python
# import pandas as pd
#
# # Sample Raw Data
# data = {
#     'ID': [101, 102, 103, 104],
#     'Name': ['Alice', 'Bob', 'Alice', 'Charlie'],
#     'Age': [25, None, 25, 29],
#     'Income': [50000, 45000, 50000, '-'],
#     'City': ['New York', 'Los Angeles', 'New York', 'Boston']
# }
#
# df = pd.DataFrame(data)
# df

# %%
import pandas as pd

df = pd.read_csv('medical_students_dataset.csv')
df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %% [markdown]
# # <center><font color='#2A9D8F'>📊 Random Sampling with `df.sample()`</font></center>
#
# ## 🔍 **What is `df.sample()`?**
# `df.sample()` is a **Pandas function** used to randomly select rows or columns from a DataFrame.
# It is useful for **data exploration, testing, and training subset creation**.
#
# ---
#
# ## ⚙️ **Basic Usage**
# ```python
# import pandas as pd
#
# # Sample DataFrame
# data = {'Product': ['A', 'B', 'C', 'D', 'E'],
#         'Sales': [100, 200, 300, 400, 500]}
# df = pd.DataFrame(data)
#
# # Randomly select 2 rows
# sampled_df = df.sample(n=2)
#
# print(sampled_df)

# %%
df.sample(5)
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 107566      7567.0  26.0    Male  168.237630  47.114408          B  16.645907
# 94763          NaN  22.0  Female         NaN        NaN          B  27.761245
# 186826     86827.0  22.0  Female  165.905291  89.742144        NaN  32.604381
# 115279     15280.0  20.0    Male  168.889813  43.276310          O  15.172017
# 3722        3723.0   NaN  Female  181.953046        NaN          O  19.966631
#
#         Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 107566    97.692811         NaN           118.0        229.0      Yes      No
# 94763           NaN        89.0           132.0        243.0       No      No
# 186826    98.240768        67.0           116.0        186.0       No      No
# 115279    98.369196        80.0            97.0        165.0       No      No
# 3722            NaN         NaN           116.0        164.0       No     Yes

# %%
df.shape
# Out:
# (200000, 13)

# %% [markdown]
# # <center><font color='##d0e024'>🧹 2.Data Cleaning — Handling Missing Data</font></center>
#
# ---
#
# ## <font color='##d0e024'>❓ What is Missing Data?</font>
#
# **Missing Data** occurs when no value is stored for a data point in a dataset. It’s a common issue in real-world datasets that can affect data analysis and machine learning models.
#
# > ⚠️ **“Missing data can lead to inaccurate conclusions if not handled properly.”**
#
# ### <font color='##d0e024'>💡 Why Does It Happen?</font>
#
# - 📝 **Human Errors:** Incomplete data entry
# - 📊 **Data Collection Issues:** Sensor failures, system crashes
# - 🕵️‍♂️ **Privacy Concerns:** Users may intentionally skip answers
# - 📆 **Time Lags:** Data yet to be recorded
#
# ---
#
# ## <font color='##d0e024'>📂 Types of Missing Data</font>
#
# 1. **MCAR — Missing Completely at Random**
#    - No relationship between missing data and any variables.
#    - *Example:* A survey form lost due to a system error.
#
# 2. **MAR — Missing at Random**
#    - Missingness depends on observed data but not on the missing data itself.
#    - *Example:* People from a certain age group are less likely to answer income questions.
#
# 3. **MNAR — Missing Not at Random**
#    - Missingness depends on unobserved data.
#    - *Example:* Patients not reporting weight due to personal concerns.
#
# <center><img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*NSOy_Fnu4AIApg6B1eGHcA.png" alt="Types of Missing Data" width="600"/></center>
#
# ---
#
# ## <font color='#ecff18'>🛠️ Methods to Handle Missing Data</font>
#
# ### ✅ **1. Removing Rows/Columns**
# - **When to use:** When missing data is minimal or non-critical.
# - ❗ *Caution:* Can result in data loss.
#
# ```python
# import pandas as pd
#
# # Sample DataFrame
# df = pd.DataFrame({
#     'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#     'Age': [24, None, 29, 35],
#     'Income': [50000, 45000, None, 70000]
# })
#
# # Drop rows with missing values
# df_cleaned = df.dropna()
# df_cleaned

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, None, 29, 35],
    'Income': [50000, 45000, None, 70000]
})

# Drop rows with missing values
df_cleaned = df.dropna()
df_cleaned
# Out:
#     Name   Age   Income
# 0  Alice  24.0  50000.0
# 3  David  35.0  70000.0

# %%
import pandas as pd

df = pd.read_csv('medical_students_dataset.csv')


# Drop rows with missing values
df_cleaned = df.dropna()
df_cleaned
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 7              8.0  28.0    Male  186.489402  52.389752         AB  15.063921
# 11            12.0  34.0  Female  182.416302  76.371050         AB  22.950992
# 19            20.0  31.0    Male  166.489929  49.955569          B  18.022207
# 22            23.0  29.0  Female  179.909041  90.679436         AB  28.015787
# ...            ...   ...     ...         ...        ...        ...        ...
# 174907     74908.0  21.0  Female  156.052614  83.194667          O  34.162795
# 174911     74912.0  29.0    Male  192.357245  66.360905         AB  17.934745
# 174912     74913.0  32.0    Male  157.199221  88.607827          A  35.856782
# 174913     74914.0  34.0  Female  174.071701  45.701372          A  15.082485
# 174917     74918.0  23.0    Male  159.547381  93.683336         AB  36.802980
#
# ...

# %%
import pandas as pd
import missingno as msno

# Loading the dataset
df = pd.read_csv('medical_students_dataset.csv')

# Visualize missing values as a matrix
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# # <center><font color='#ffb218'>📊 3.Imputation Techniques</font></center>
#
# ---
#
# ## <font color='#ffb218'>🔸 Mean/Median/Mode Imputation</font>
#
# Replace missing values with statistical measures like **mean**, **median**, or **mode**.
# **Best for:** Numeric data with minimal outliers.
#
# ```python
# import pandas as pd
#
# # Sample DataFrame
# df = pd.DataFrame({
#     'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#     'Age': [24, None, 29, 35],
#     'Income': [50000, 45000, None, 70000]
# })
#
# # Fill missing 'Age' with the mean
# df['Age'].fillna(df['Age'].mean(), inplace=True)
# df

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, None, 29, 35],
    'Income': [50000, 45000, None, 70000]
})

# Fill missing 'Age' with the mean
df['Age'].fillna(df['Age'].mean(), inplace=True)
df
# Out:
#       Name        Age   Income
# 0    Alice  24.000000  50000.0
# 1      Bob  29.333333  45000.0
# 2  Charlie  29.000000      NaN
# 3    David  35.000000  70000.0

# %%
import pandas as pd

df = pd.read_csv('medical_students_dataset.csv')

# Fill missing 'Age' with the mean
df['BMI'].fillna(df['BMI'].mean(), inplace=True)
df
# Out:
# <ipython-input-7-7e37ea666c48>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BMI'].fillna(df['BMI'].mean(), inplace=True)
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B  23.338869
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# ...

# %%
# Out:
# <bound method NDFrame.sample of       Name   Age   Income
# 0    Alice  24.0  50000.0
# 1      Bob   NaN  45000.0
# 2  Charlie  29.0      NaN
# 3    David  35.0  70000.0>

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)
df["Height"].fillna(df["Height"].mean(), inplace=True)
df["Weight"].fillna(df["Weight"].mean(), inplace=True)
df["BMI"].fillna(df["BMI"].mean(), inplace=True)
df["Temperature"].fillna(df["Temperature"].median(), inplace=True)
df["Heart Rate"].fillna(df["Heart Rate"].mean(), inplace=True)
df["Blood Pressure"].fillna(df["Blood Pressure"].mean(), inplace=True)
df["Cholesterol"].fillna(df["Cholesterol"].median(), inplace=True)
df['Student ID'] = df['Student ID'].interpolate()
df
# Out:
# <ipython-input-8-91cdeba7cd23>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(), inplace=True)
# <ipython-input-8-91cdeba7cd23>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# <font color='#ffb218'>🔸 Forward-Fill & Backward-Fill
# </font>
# Fills missing values using nearby data points.
#
# Forward-Fill: Fills with the last valid observation
# Backward-Fill: Fills with the next valid observation

# %%
# Forward Fill (fill from top to bottom)
df.ffill()

# Backward Fill (fill from bottom to top)
df.bfill()
# Out:
#        Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0             1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1             2.0  32.0    Male  152.069157  47.630941          B  16.729017
# 2             3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3             5.0  30.0    Male  182.112867  63.332207          B  19.096042
# 4             5.0  23.0  Female  151.491294  46.234173          O  29.912403
# ...           ...   ...     ...         ...        ...        ...        ...
# 87460     87461.0  21.0  Female  178.823613  63.136732          A  19.743874
# 87461     87462.0  33.0  Female  181.334903  44.650677          A  13.578920
# 87462     87463.0  34.0    Male  154.612016  85.940007          A        NaN
# 87463     87464.0  24.0    Male  170.084026  93.435422         AB        NaN
# 87464     87465.0  21.0  Female  198.010816  97.075100        NaN        NaN
#
# ...

# %%
df.ffill()

df.bfill()
# Out:
#       Name   Age   Income
# 0    Alice  24.0  50000.0
# 1      Bob  29.0  45000.0
# 2  Charlie  29.0  70000.0
# 3    David  35.0  70000.0

# %% [markdown]
# <font color='##ffc818'>🔸 Predictive Imputation (KNN, ML Models)</font>
# Uses machine learning models (like KNN) to predict and fill missing data.

# %%
from sklearn.impute import KNNImputer
import numpy as np

# Sample DataFrame
df_knn = pd.DataFrame({
    'Age': [24, np.nan, 29, 35],
    'Income': [50000, 45000, np.nan, 70000]
})

# Apply KNN Imputer
imputer = KNNImputer(n_neighbors=2)
df_imputed = pd.DataFrame(imputer.fit_transform(df_knn), columns=df_knn.columns)
df_imputed
# Out:
#     Age   Income
# 0  24.0  50000.0
# 1  29.5  45000.0
# 2  29.0  60000.0
# 3  35.0  70000.0

# %% [markdown]
# # <center><font color='#4C4C9D'>📊 4.Handling Outliers</font></center>
#
# ---
#
# ## <font color='#4C4C9D'>💡 What Are Outliers?</font>
#
# **Outliers** are data points that significantly differ from other observations.
# They can occur due to:
# - **Data entry errors**
# - **Measurement variability**
# - **Natural deviations** in the data
#
# ⚠️ **Why Care?**
# Outliers can **skew analysis**, impact **model accuracy**, and lead to **misleading insights**.
#
# ---
#
# ## <font color='#4C4C9D'>🔍 Outlier Detection Methods</font>
#
# ### 📦 **1. Boxplots (IQR Method)**
# - Detect outliers using the **Interquartile Range (IQR)**.
#
# ```python
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Sample DataFrame
# df = pd.DataFrame({'Score': [45, 48, 50, 52, 47, 200, 49, 53, 51, 46]})
#
# # Boxplot Visualization
# sns.boxplot(x=df['Score'])
# plt.title('Boxplot for Outlier Detection')
# plt.show()
#
# # IQR Calculation
# Q1 = df['Score'].quantile(0.25)
# Q3 = df['Score'].quantile(0.75)
# IQR = Q3 - Q1
#
# # Outlier Boundaries
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
#
# # Detecting Outliers
# outliers = df[(df['Score'] < lower_bound) | (df['Score'] > upper_bound)]
# outliers

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame
df = pd.DataFrame({'Score': [45, 48, 50, 52, 47, 200, 49, 53, 51, 46]})

# Boxplot Visualization
sns.boxplot(x=df['Score'])
plt.title('Boxplot for Outlier Detection')
plt.show()

# IQR Calculation
Q1 = df['Score'].quantile(0.25)
Q3 = df['Score'].quantile(0.75)
IQR = Q3 - Q1

# Outlier Boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Detecting Outliers
outliers = df[(df['Score'] < lower_bound) | (df['Score'] > upper_bound)]
outliers
# Out:
#    Score
# 5    200

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame
df = pd.read_csv('medical_students_dataset.csv')
# Boxplot Visualization
sns.boxplot(x=df['Age'])
plt.title('Boxplot for Outlier Detection')
plt.show()

# IQR Calculation
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1

# Outlier Boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Detecting Outliers
outliers = df[(df['Age'] < lower_bound) | (df['Age'] > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [Student ID, Age, Gender, Height, Weight, Blood Type, BMI, Temperature, Heart Rate, Blood Pressure, Cholesterol, Diabetes, Smoking]
# Index: []

# %% [markdown]
# # <center><font color='#2A9D8F'>📊 2.Scatter Plot</font></center>
#
# ## 🔍 **Why Use a Scatter Plot for Outlier Detection?**
# A scatter plot helps identify **outliers** by visualizing relationships between two numerical variables.
# Outliers typically appear as points far from the main cluster, making them easy to spot.
#
# ---
#
# ## 💻 **Python Code:**
# ```python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Data with Outliers
np.random.seed(42)
x = np.random.normal(50, 10, 100)  # Normally distributed data
y = np.random.normal(50, 10, 100)

# Adding outliers
x = np.append(x, [120, 130, 140])
y = np.append(y, [120, 130, 140])

# Create DataFrame
df = pd.DataFrame({'X': x, 'Y': y})

# Scatter Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['X'], y=df['Y'], color='blue', label='Data Points')

# Highlight Outliers (values > 100 in this case)
outliers = df[(df['X'] > 100) | (df['Y'] > 100)]
sns.scatterplot(x=outliers['X'], y=outliers['Y'], color='red', label='Outliers', s=100, marker='X')

plt.title('Scatter Plot for Outlier Detection')
plt.xlabel('Feature X')
plt.ylabel('Feature Y')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('medical_students_dataset.csv')

x_feature = 'Cholesterol'
y_feature = 'Heart Rate'


plt.figure(figsize=(10, 6))
sns.scatterplot(x=df[x_feature], y=df[y_feature])


plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.title(f'Outlier Detection: {x_feature} vs. {y_feature}')

plt.show()

# %% [markdown]
# # <center><font color='#4C4C9D'>📊  5.Z-Score Method</font></center>
#
# ---
#
# ## <font color='#4C4C9D'>💡 What is Z-Score?</font>
# The **Z-Score** measures how many **standard deviations** a data point is from the mean.
# - Data points with **|Z-Score| > 3** are typically considered **outliers**.
#
# ---
#
# ### 🧮 **Z-Score Calculation Example**
#
# ```python
# from scipy import stats
# import pandas as pd
# import numpy as np
#
# # Sample DataFrame
# df = pd.DataFrame({'Score': [45, 48, 50, 52, 47, 200, 49, 53, 51, 46]})
#
# # Z-Score Calculation
# df['Z_Score'] = stats.zscore(df['Score'])
#
# # Outliers: Z-Score > 3 or < -3
# df_outliers = df[np.abs(df['Z_Score']) > 3]
# df_outliers

# %%
from scipy import stats
import pandas as pd
import numpy as np

# Sample DataFrame
df = pd.DataFrame({'Score': [45, 48, 50, 52, 47, 200, 49, 53, 51, 46]})

# Z-Score Calculation
df['Z_Score'] = stats.zscore(df['Score'])

# Outliers: Z-Score > 3 or < -3
df_outliers = df[np.abs(df['Z_Score']) > 3]
df_outliers
# Out:
# Empty DataFrame
# Columns: [Score, Z_Score]
# Index: []

# %%
import pandas as pd
from scipy import stats


df['Cholesterol'] = pd.to_numeric(df['Cholesterol'], errors='coerce')
df = df.dropna(subset=['Cholesterol'])

df['Cholesterol_Z_Score'] = stats.zscore(df['Cholesterol'])


print(df[['Cholesterol', 'Cholesterol_Z_Score']])
# Out:
#        Cholesterol  Cholesterol_Z_Score
# 0            203.0             0.493197
# 1            163.0            -0.572266
# 2            216.0             0.839473
# 3            141.0            -1.158271
# 4            231.0             1.239021
# ...            ...                  ...
# 87459        212.0             0.732926
# 87460        248.0             1.691843
# 87461        246.0             1.638570
# 87462        235.0             1.345568
# 87463        140.0            -1.184907
#
# [78789 rows x 2 columns]
# <ipython-input-5-939f5554c791>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cholesterol_Z_Score'] = stats.zscore(df['Cholesterol'])

# %% [markdown]
# # <center><font color='#2A9D8F'>📏 6.Feature Scaling in Machine Learning</font></center>
#
# ---
#
# ## <font color='#2A9D8F'>💡 Why is Feature Scaling Important?</font>
#
# Machine learning algorithms often rely on **distance-based calculations** (e.g., KNN, SVM, Gradient Descent).
# Unscaled data can lead to **biased models** where features with larger ranges dominate others.
#
# 🔑 **Key Reasons to Scale Data:**
# - ⚖️ Ensures **fair weight** across features
# - 🚀 Improves **convergence speed** in gradient-based models
# - 📊 Enhances **accuracy** for distance-based algorithms (e.g., KNN, SVM)
#
# ---
#
# # <center><font color='#2A9D8F'>🔄 Types of Feature Scaling</font></center>
#
# | **Scaling Method**   | 📏 **Definition**                    | 📊 **Best For**                   |
# |---------------------|--------------------------------------|----------------------------------|
# | **Standardization**  | Centers data (Mean = 0, Std = 1)    | Linear Regression, PCA, SVM     |
# | **Normalization**    | Scales to range [0, 1]              | KNN, Neural Networks            |
# | **Log Transformation** | Compresses large ranges            | Skewed Distributions            |
#
# ---
#
# # <center><font color='#2A9D8F'>⚖️ Standardization (Z-Score Scaling)</font></center>
#
# ## **Formula:**
# <center><img src="https://www.thoughtco.com/thmb/dLIR3gpIly-lldGfbtf59kgI1qs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/zscore-56a8fa785f9b58b7d0f6e87b.GIF"
#  width="300" style="margin:10px auto;"/></center>
#
# ### 💡 **When to Use:**
# - Linear Models (e.g., **Linear Regression**)
# - Dimensionality Reduction (**PCA**)
# - Distance-based models (**SVM**, **Logistic Regression**)
#
# ---
#
# ### 🧮 **StandardScaler Example (Scikit-learn)**
#
# ```python
# from sklearn.preprocessing import StandardScaler
# import pandas as pd
#
# # Sample DataFrame
# df = pd.DataFrame({'Age': [25, 30, 45, 35, 50], 'Salary': [40000, 50000, 80000, 60000, 90000]})
#
# # Apply Standardization
# scaler = StandardScaler()
# df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
# df_scaled

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({'Age': [25, 30, 45, 35, 50], 'Salary': [40000, 50000, 80000, 60000, 90000]})

df
# Out:
#    Age  Salary
# 0   25   40000
# 1   30   50000
# 2   45   80000
# 3   35   60000
# 4   50   90000

# %%
# Apply Standardization
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
df_scaled
# Out:
#         Age    Salary
# 0 -1.293993 -1.293993
# 1 -0.754829 -0.754829
# 2  0.862662  0.862662
# 3 -0.215666 -0.215666
# 4  1.401826  1.401826

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

df = pd.read_csv('medical_students_dataset.csv')
df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler


df = pd.read_csv('medical_students_dataset.csv')


numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns


df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df[numeric_cols]), columns=numeric_cols)


df_final = pd.concat([df_scaled, df.drop(numeric_cols, axis=1).reset_index(drop=True)], axis=1)


print(df_final.head())
df.sample(5)
# Out:
#    Student ID       Age        Height    Weight       BMI   Temperature  \
# 0   -1.823996 -1.728953 -9.608247e-01  0.145030  0.645471  2.992746e-14
# 1   -1.823960  0.000000 -1.669177e+00 -1.359450  0.000000  2.401400e-01
# 2   -1.823923  1.288582  5.538081e-01 -0.865940 -0.990597 -7.174048e-01
# 3    0.000000  0.857505  5.228149e-01 -0.404013 -0.635859  5.026013e-01
# 4   -1.823850 -0.651262 -4.147302e-15 -1.444445  0.000000 -2.546949e-01
#
#    Heart Rate  Blood Pressure  Cholesterol  Gender Blood Type Diabetes Smoking
# 0    1.415376       -0.406759     0.519577  Female          O       No     NaN
# 1    1.232703       -0.772679    -0.603005    Male          B       No      No
# 2   -0.320023        1.130105     0.884416  Female          A      Yes      No
# 3    1.780723       -0.187207    -1.220425    Male          B       No     Yes
# 4    1.415376        0.000000     1.305384  Female          O       No      No
# ...

# %% [markdown]
# # <center><font color='#2A9D8F'>🌟 7.Normalization (Min-Max Scaling)</font></center>
#
# ## **📏 Formula:**
# <center><img src="https://www.oreilly.com/api/v2/epubs/9781788393485/files/assets/545d977f-9de2-4280-b08a-0436149980c5.png"
#  width="300" style="margin:10px auto;"/></center>
#
#
# This transformation scales data to a **[0, 1]** range, ensuring that all features contribute equally to the model.
#
# ---
#
# ## 💡 **When to Use Normalization:**
# - 📊 **Distance-based models** (*KNN*, *K-Means*) — These models rely on distance metrics, so scaling prevents bias.
# - 🤖 **Neural Networks** — Gradient Descent converges faster with features scaled between 0 and 1.
#
# ---
#
# ## 🧮 **MinMaxScaler Example (Scikit-learn)**
#
# ```python
# from sklearn.preprocessing import MinMaxScaler
# import pandas as pd
#
# # Sample DataFrame
# df = pd.DataFrame({'Age': [25, 30, 45, 35, 50], 'Salary': [40000, 50000, 80000, 60000, 90000]})
#
# # Apply Normalization
# scaler = MinMaxScaler()
# df_normalized = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
# df_normalized

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({'Age': [25, 30, 45, 35, 50], 'Salary': [40000, 50000, 80000, 60000, 90000]})

# Apply Normalization
scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
df_normalized
# Out:
#    Age  Salary
# 0  0.0     0.0
# 1  0.2     0.2
# 2  0.8     0.8
# 3  0.4     0.4
# 4  1.0     1.0

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('medical_students_dataset.csv')

numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df[numeric_cols]), columns=numeric_cols)

df_final = pd.concat([df_normalized, df.drop(numeric_cols, axis=1).reset_index(drop=True)], axis=1)

print(df_final.head())
# Out:
#    Student ID       Age    Height    Weight       BMI  Temperature  \
# 0    0.000000  0.000000  0.235564  0.539246  0.512569     0.497651
# 1    0.000010  0.501348  0.041383  0.127174  0.386929     0.523409
# 2    0.000020  0.875000  0.650771  0.262345  0.194111     0.420702
# 3    0.499735  0.750000  0.642275  0.388865  0.263160     0.551560
# 4    0.000040  0.312500  0.498955  0.103894  0.386929     0.470333
#
#    Heart Rate  Blood Pressure  Cholesterol  Gender Blood Type Diabetes Smoking
# 0    0.897436        0.387755     0.643411  Female          O       No     NaN
# 1    0.846154        0.285714     0.333333    Male          B       No      No
# 2    0.410256        0.816327     0.744186  Female          A      Yes      No
# 3    1.000000        0.448980     0.162791    Male          B       No     Yes
# 4    0.897436        0.501184     0.860465  Female          O       No      No

# %% [markdown]
# # <center><font color='#E76F51'>🎯 8.Encoding Categorical Variables</font></center>
#
# ## **📖 Definition & Importance**
# Categorical variables contain discrete values (*e.g., Gender, Country, Product Type*) that machine learning models cannot process directly. **Encoding** transforms these categories into numerical values, making them suitable for algorithms.
#
# **Why is it important?**
# - 🚀 **Improves model performance**
# - 🤖 **Enables algorithms to interpret data correctly**
# - 📊 **Prevents bias caused by categorical ordering**
#
# ---
#
# ## 🏷️ **1. Label Encoding**
# Assigns a unique integer to each category. Ideal for **ordinal data** (*e.g., Small < Medium < Large*).
#
# ```python
# from sklearn.preprocessing import LabelEncoder
#
# # Sample Data
# import pandas as pd
# df = pd.DataFrame({'Size': ['Small', 'Medium', 'Large', 'Small', 'Large']})
#
# # Apply Label Encoding
# le = LabelEncoder()
# df['Size_encoded'] = le.fit_transform(df['Size'])
# df

# %%
from sklearn.preprocessing import LabelEncoder

# Sample Data
import pandas as pd
df = pd.DataFrame({'Size': ['Small', 'Medium', 'Large', 'Small', 'Large']})

# Apply Label Encoding
le = LabelEncoder()
df['Size_encoded'] = le.fit_transform(df['Size'])
df
# Out:
#      Size  Size_encoded
# 0   Small             2
# 1  Medium             1
# 2   Large             0
# 3   Small             2
# 4   Large             0

# %%
from sklearn.preprocessing import LabelEncoder

import pandas as pd

df = pd.read_csv('medical_students_dataset.csv')

# Apply Label Encoding
le = LabelEncoder()
df['Blood Type_encoded'] = le.fit_transform(df['Blood Type'])
df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %% [markdown]
# # <center><font color='#2A9D8F'>🎨 8.1.2 One-Hot Encoding</font></center>
#
# ## 📖 **Definition:**
# One-Hot Encoding transforms **categorical variables** into **binary columns** (0 or 1) for each unique category. It’s ideal for **nominal data** where no natural ordering exists (*e.g., Country, Color*).
#
# ---
#
# ## 🧠 **Why Use One-Hot Encoding?**
# - ✅ **Prevents false ordinal relationships**
# - 📊 **Makes data interpretable for ML models**
# - 🚀 **Works well with distance-based algorithms (e.g., KNN, SVM)**
#
# ---
#
# ## 🐍 **Python Example (Pandas)**
#
# ```python
# import pandas as pd
#
# # Sample DataFrame
# df = pd.DataFrame({'Color': ['Red', 'Blue', 'Green', 'Blue']})
#
# # Apply One-Hot Encoding
# df_encoded = pd.get_dummies(df, columns=['Color'])
# print(df_encoded)

# %%
import pandas as pd
df = pd.read_csv('medical_students_dataset.csv')

df_encoded = pd.get_dummies(df, columns=['Blood Type'])
print(df_encoded)
# Out:
#         Student ID   Age  Gender      Height     Weight        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941        NaN
# 2              3.0  32.0  Female  182.537664  55.741083  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207  19.096042
# 4              5.0  23.0  Female         NaN  46.234173        NaN
# ...            ...   ...     ...         ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405  42.175189
#
#         Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking  \
# 0               NaN        95.0           109.0        203.0       No     NaN
# ...

# %% [markdown]
# # <center><font color='#F4A261'>🎯 8.1.3 Target Encoding</font></center>
#
# ## 📖 **Definition:**
# **Target Encoding** replaces each category with the **mean of the target variable** for that category. It’s highly effective for **high-cardinality features** (*e.g., cities, user IDs*) and works well with **tree-based models**.
#
# ---
#
# ## 🧠 **When to Use Target Encoding?**
# - 📊 **High-cardinality features** (many unique values)
# - 🌳 **Tree-based models** (*Random Forest, XGBoost*)
# - ⚖️ **When dimensionality needs to be controlled**
#
# 💡 **Avoid using with linear models** without regularization — it may introduce **data leakage**.
#
# ---
#
# ## 🐍 **Python Example (Target Encoding with `category_encoders`)**
#
# ```python
# import pandas as pd
# import category_encoders as ce
#
# # Sample Data
# df = pd.DataFrame({
#     'City': ['NY', 'LA', 'NY', 'Chicago', 'LA'],
#     'Sales': [300, 400, 350, 500, 450]
# })
#
# # Apply Target Encoding
# encoder = ce.TargetEncoder(cols=['City'])
# df['City_encoded'] = encoder.fit_transform(df['City'], df['Sales'])
# print(df)

# %%
# !pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import category_encoders as ce

# Load the dataset
df = pd.read_csv('medical_students_dataset.csv')

df['Gender'] = df['Gender'].fillna('Unknown')
df['Temperature'] = df['Temperature'].fillna(df['Temperature'].mean())

encoder = ce.TargetEncoder(cols=['Gender'])
df['Gender_encoded'] = encoder.fit_transform(df['Gender'], df['Temperature'])

print(df[['Gender', 'Temperature', 'Gender_encoded']])
# Out:
#         Gender  Temperature  Gender_encoded
# 0       Female    98.600948       98.601124
# 1         Male    98.714977       98.600285
# 2       Female    98.260293       98.601124
# 3         Male    98.839605       98.600285
# 4       Female    98.480008       98.601124
# ...        ...          ...             ...
# 199995    Male    99.170685       98.600285
# 199996  Female    97.865785       98.601124
# 199997  Female    98.768210       98.601124
# 199998  Female    98.994212       98.601124
# 199999  Female    98.595817       98.601124
#
# [200000 rows x 3 columns]

# %% [markdown]
# # <center><font color='#E76F51'>🔍 9.Feature Extraction</font></center>
#
# ## 📖 **Definition:**
# **Feature Extraction** is the process of transforming raw data into meaningful features that enhance model performance. It helps in **reducing dimensionality**, **improving accuracy**, and **simplifying datasets**.
#
# ---
#
# ## 🤔 **Why Is Feature Extraction Important?**
# - 🌟 **Improves model efficiency** by reducing noise and redundancy.
# - 📊 **Enhances interpretability** of complex datasets.
# - ⚡ **Boosts performance** of ML algorithms, especially with high-dimensional data.
#
# ---
#
# # 🛠️ **Feature Extraction Methods**
#
# ## 🧮 **1. Principal Component Analysis (PCA)**
# Reduces dimensionality by transforming features into **principal components** while preserving variance.
#
# ### ✅ **When to Use:**
# - Large datasets with many correlated features
# - Preprocessing for algorithms sensitive to multicollinearity (*e.g., Linear Regression*)
#
# ```python
# from sklearn.decomposition import PCA
# import pandas as pd
#
# # Sample Data
# df = pd.DataFrame({
#     'Math': [90, 85, 78, 92],
#     'Physics': [85, 80, 75, 88],
#     'Chemistry': [88, 82, 79, 90]
# })
#
# # Apply PCA
# pca = PCA(n_components=2)
# pca_result = pca.fit_transform(df)
# print("PCA Result:\n", pca_result)

# %%
from sklearn.decomposition import PCA
import pandas as pd


df = pd.DataFrame({
    'Math': [90, 85, 78, 92],
    'Physics': [85, 80, 75, 88],
    'Chemistry': [88, 82, 79, 90]
})

pca = PCA(n_components=2)
pca_result = pca.fit_transform(df)
print("PCA Result:\n", pca_result)
# Out:
# PCA Result:
#  [[  5.78075454   0.08980202]
#  [ -3.36664837  -1.334639  ]
#  [-12.22756913   0.78165783]
#  [  9.81346296   0.46317915]]

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt


df = pd.read_csv('medical_students_dataset.csv')


numeric_cols = ['Age', 'Height', 'Weight', 'BMI', 'Temperature', 'Heart Rate',
                'Blood Pressure', 'Cholesterol']

imputer = SimpleImputer(strategy='mean')
df[numeric_cols] = imputer.fit_transform(df[numeric_cols])

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[numeric_cols])

pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_scaled)


explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)


plt.figure(figsize=(8, 6))
plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.7, c=df['Age'], cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Medical Students Dataset')
plt.colorbar(label='Age')
plt.show()
# Out:
# Explained Variance Ratio: [0.23629569 0.12643592]

# %% [markdown]
# # <center><font color='#264653'>📖 Text Feature Extraction</font></center>
#
# ## 🔸 **TF-IDF (Term Frequency-Inverse Document Frequency)**
# **TF-IDF** transforms text into numerical features by measuring how important a word is to a document within a collection. It reduces the impact of frequently used words that carry less meaning (*e.g., "the", "is"*) and highlights unique terms.
#
# ### 💡 **Formula:**
# https://miro.medium.com/v2/resize:fit:750/format:webp/1*FlWuw1ilzO3ZXevpA0S0Gg.png
#
# ### 🛠️ **TF-IDF Example (Scikit-learn):**
# ```python
# from sklearn.feature_extraction.text import TfidfVectorizer
# import pandas as pd
#
# # Sample Text
# docs = ["Data Science is cool", "Machine Learning is powerful"]
#
# # Apply TF-IDF
# vectorizer = TfidfVectorizer()
# tfidf_matrix = vectorizer.fit_transform(docs)
#
# # View Result as DataFrame
# df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
# print(df_tfidf)

# %% [markdown]
# # <center><font color='#264653'>📖 Text Feature Extraction</font></center>
#
# ## 🔸 **TF-IDF (Term Frequency-Inverse Document Frequency)**
# **TF-IDF** transforms text into numerical features by measuring how important a word is to a document within a collection. It reduces the impact of frequently used words that carry less meaning (*e.g., "the", "is"*) and highlights unique terms.
#
# ### 💡 **Formula:**
# <center><img src="https://miro.medium.com/v2/resize:fit:750/format:webp/1*FlWuw1ilzO3ZXevpA0S0Gg.png"
#  width="300" style="margin:10px auto;"/></center>
#
#
# ### 🛠️ **TF-IDF Example (Scikit-learn):**
# ```python
# from sklearn.feature_extraction.text import TfidfVectorizer
# import pandas as pd
#
# # Sample Text
# docs = ["Data Science is cool", "Machine Learning is powerful"]
#
# # Apply TF-IDF
# vectorizer = TfidfVectorizer()
# tfidf_matrix = vectorizer.fit_transform(docs)
#
# # View Result as DataFrame
# df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
# print(df_tfidf)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

docs = ["Data Science is cool", "Machine Learning is powerful"]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(docs)

df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
print(df_tfidf)
# Out:
#        cool      data        is  learning   machine  powerful   science
# 0  0.534046  0.534046  0.379978  0.000000  0.000000  0.000000  0.534046
# 1  0.000000  0.000000  0.379978  0.534046  0.534046  0.534046  0.000000

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer


df = pd.read_csv('medical_students_dataset.csv')
df['combined_text'] = df[['Gender', 'Blood Type', 'Diabetes', 'Smoking']].astype(str).agg(' '.join, axis=1)

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df['combined_text'])

df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
print(df_tfidf.head())
# Out:
#     ab    female      male       nan        no       yes
# 0  0.0  0.612419  0.000000  0.704173  0.359282  0.000000
# 1  0.0  0.000000  0.648633  0.000000  0.761102  0.000000
# 2  0.0  0.569714  0.000000  0.000000  0.334229  0.750811
# 3  0.0  0.000000  0.569691  0.000000  0.334236  0.750826
# 4  0.0  0.648656  0.000000  0.000000  0.761082  0.000000

# %% [markdown]
# # <center><font color='#E76F51'>📊 10.Feature Selection </font></center>
#
# **Feature Selection** is the process of selecting the most relevant features from a dataset to improve model performance and reduce overfitting. It helps in simplifying models, speeding up training time, and improving accuracy.
#
# ---
#
# ## ⚡ **Why It’s Important:**
# - **Reduces Overfitting:** Fewer features reduce the risk of noise influencing the model.
# - **Improves Accuracy:** Focus on relevant data leads to better predictions.
# - **Speeds Up Training:** Less data means faster computation.
# - **Simplifies Interpretation:** Easier to explain the model’s decisions.
#
# ---
#
# # 🛠️ **Feature Selection Methods**
#
# ## 🔹 **1. Filter Methods** *(Statistical techniques to rank features independently of models)*
# - **Correlation Matrix:** Remove highly correlated variables.
# - **Chi-Square Test:** Evaluates the relationship between categorical features and target.
#
# ```python
# import pandas as pd
# from sklearn.feature_selection import chi2
# from sklearn.feature_selection import SelectKBest
#
# # Sample Data
# df = pd.DataFrame({'Feature1': [1, 2, 3, 4, 5],
#                    'Feature2': [2, 4, 6, 8, 10],
#                    'Target': [0, 1, 0, 1, 0]})
#
# # Apply Chi-Square Test
# X = df[['Feature1', 'Feature2']]
# y = df['Target']
#
# chi2_selector = SelectKBest(score_func=chi2, k=1)
# X_kbest = chi2_selector.fit_transform(X, y)
# print("Selected Features:\n", X_kbest)

# %%
import pandas as pd
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

df = pd.DataFrame({'Feature1': [1, 2, 3, 4, 5],
                   'Feature2': [2, 4, 6, 8, 10],
                   'Target': [0, 1, 0, 1, 0]})

X = df[['Feature1', 'Feature2']]
y = df['Target']

chi2_selector = SelectKBest(score_func=chi2, k=1)
X_kbest = chi2_selector.fit_transform(X, y)
print("Selected Features:\n", X_kbest)
# Out:
# Selected Features:
#  [[ 2]
#  [ 4]
#  [ 6]
#  [ 8]
#  [10]]

# %%
import pandas as pd
from sklearn.feature_selection import chi2, SelectKBest
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

df = pd.read_csv('medical_students_dataset.csv')


features = ['Age', 'Height', 'Weight', 'BMI', 'Temperature', 'Heart Rate', 'Blood Pressure', 'Cholesterol']
target = 'Diabetes'


label_encoder = LabelEncoder()
df[target] = label_encoder.fit_transform(df[target].astype(str))

df[features] = df[features].fillna(df[features].mean())

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(df[features])


chi2_selector = SelectKBest(score_func=chi2, k=5)
X_kbest = chi2_selector.fit_transform(X_scaled, df[target])

selected_features = [features[i] for i in chi2_selector.get_support(indices=True)]
print("Top 5 Features based on Chi-Square Test:\n", selected_features)
# Out:
# Top 5 Features based on Chi-Square Test:
#  ['Age', 'Height', 'Weight', 'BMI', 'Cholesterol']

# %% [markdown]
# # 🔸 **Wrapper Methods (Use predictive models to score feature subsets)**
#
# **Recursive Feature Elimination (RFE):**
# RFE is a recursive method that removes less significant features based on model performance, aiming to select features that contribute the most to prediction accuracy.
#
# ---
#
# ## ⚡ **How It Works:**
# 1. Trains a model on all features.
# 2. Evaluates feature importance using model coefficients.
# 3. Eliminates the least important feature(s).
# 4. Repeats steps 1-3 until the desired number of features remains.
#
# ---
#
# ### 🛠️ **Example Using RFE with Logistic Regression**
#
# ```python
# from sklearn.feature_selection import RFE
# from sklearn.linear_model import LogisticRegression
# import pandas as pd
#
# # Sample Data
# df = pd.DataFrame({
#     'Feature1': [1, 2, 3, 4, 5],
#     'Feature2': [5, 4, 3, 2, 1],
#     'Feature3': [2, 3, 4, 5, 6],
#     'Target': [0, 1, 0, 1, 0]
# })
#
# X = df[['Feature1', 'Feature2', 'Feature3']]
# y = df['Target']
#
# # Logistic Regression Model
# model = LogisticRegression()
#
# # Apply RFE to select the top feature
# rfe = RFE(estimator=model, n_features_to_select=1)
# fit = rfe.fit(X, y)
#
# # Display Results
# print("Num Features Selected:", fit.n_features_)
# print("Selected Features:", fit.support_)
# print("Feature Ranking:", fit.ranking_)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pandas as pd

# Sample Data
df = pd.DataFrame({
    'Feature1': [1, 2, 3, 4, 5],
    'Feature2': [5, 4, 3, 2, 1],
    'Feature3': [2, 3, 4, 5, 6],
    'Target': [0, 1, 0, 1, 0]
})

X = df[['Feature1', 'Feature2', 'Feature3']]
y = df['Target']

# Logistic Regression Model
model = LogisticRegression()

# Apply RFE to select the top feature
rfe = RFE(estimator=model, n_features_to_select=1)
fit = rfe.fit(X, y)

# Display Results
print("Num Features Selected:", fit.n_features_)
print("Selected Features:", fit.support_)
print("Feature Ranking:", fit.ranking_)
# Out:
# Num Features Selected: 1
# Selected Features: [False  True False]
# Feature Ranking: [3 1 2]

# %% [markdown]
# # 🔸 **Embedded Methods (Feature selection during model training)**
#
# **Lasso Regression (L1 Regularization):**
# Lasso adds a penalty equal to the absolute value of the magnitude of coefficients, effectively shrinking less important feature coefficients to zero. This results in a simpler, more interpretable model by automatically selecting features.
#
# ---
#
# ## ⚡ **How It Works:**
# - Adds **L1 regularization** term to the loss function.
# - Coefficients of less important features are reduced to zero.
# - Only features with non-zero coefficients are retained.
#
# **Lasso Objective Function:**
# $$
# \text{Minimize} \left( \sum_{i=1}^{n}(y_i - \hat{y}_i)^2 + \alpha \sum_{j=1}^{p} |w_j| \right)
# $$
# Where:
# - \( \alpha \) controls the strength of regularization.
# - Higher \( \alpha \) → more coefficients set to zero.
#
# ---
#
# ### 🛠️ **Example Using Lasso Regression for Feature Selection**
#
# ```python
# from sklearn.linear_model import Lasso
# from sklearn.feature_selection import SelectFromModel
# import pandas as pd
#
# # Sample Data
# df = pd.DataFrame({
#     'Feature1': [1, 2, 3, 4, 5],
#     'Feature2': [5, 4, 3, 2, 1],
#     'Feature3': [2, 3, 4, 5, 6],
#     'Target': [0, 1, 0, 1, 0]
# })
#
# X = df[['Feature1', 'Feature2', 'Feature3']]
# y = df['Target']
#
# # Apply Lasso Regression
# lasso = Lasso(alpha=0.01)
# lasso.fit(X, y)
#
# # Select important features
# model = SelectFromModel(lasso, prefit=True)
# X_selected = model.transform(X)
#
# # Output selected features
# print("Lasso Selected Features:\n", X_selected)

# %% [markdown]
# # <center><font color='#2A9D8F'>📊 Correlation Matrix in Python</font></center>
#
# ## 🔍 **What is a Correlation Matrix?**
# A **correlation matrix** is a table showing **correlation coefficients** between variables in a dataset.
# It helps understand **relationships between numerical features** in machine learning and data analysis.
#
# ---
#
# ## 📌 **Types of Correlation**
# | Type | Description |
# |------|-------------|
# | **Positive Correlation (+1)** | As one variable increases, the other also increases. |
# | **Negative Correlation (-1)** | As one variable increases, the other decreases. |
# | **No Correlation (0)** | No relationship between variables. |
#
# ---
#
# ## ⚙️ **Generate a Correlation Matrix in Python**
# ```python
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# np.random.seed(42)
# data = {'Sales': np.random.randint(100, 500, 10),
#         'Profit': np.random.randint(10, 100, 10),
#         'Customers': np.random.randint(50, 200, 10)}
# df = pd.DataFrame(data)
#
#
# corr_matrix = df.corr()
# print(corr_matrix)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


np.random.seed(42)
data = {'Sales': np.random.randint(100, 500, 10),
        'Profit': np.random.randint(10, 100, 10),
        'Customers': np.random.randint(50, 200, 10)}
df = pd.DataFrame(data)

corr_matrix = df.corr()
print(corr_matrix)
# Out:
#               Sales    Profit  Customers
# Sales      1.000000  0.387629   0.540284
# Profit     0.387629  1.000000  -0.097883
# Customers  0.540284 -0.097883   1.000000

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('medical_students_dataset.csv')

columns_for_corr = ['Temperature', 'Heart Rate', 'Blood Pressure', 'Cholesterol']
df_corr = df[columns_for_corr].corr()

print(df_corr)

plt.figure(figsize=(8, 6))
sns.heatmap(df_corr, annot=True, cmap='coolwarm', fmt=".5f", linewidths=0.5)
plt.title('Correlation Matrix of Medical Data')
plt.show()
# Out:
#                 Temperature  Heart Rate  Blood Pressure  Cholesterol
# Temperature        1.000000   -0.004072       -0.003579     0.000159
# Heart Rate        -0.004072    1.000000        0.003121     0.004760
# Blood Pressure    -0.003579    0.003121        1.000000     0.002858
# Cholesterol        0.000159    0.004760        0.002858     1.000000

# %% [markdown]
# # 📊 **11.Log & Power Transformations**
#
# ## 📖 **Definition:**
# Log and power transformations are mathematical techniques used to **reshape data distributions**, often to reduce skewness and make data more suitable for machine learning algorithms that assume normality (e.g., linear regression).
#
# ---
#
# ## 💡 **When to Use:**
# - **Skewed Data:** Helps in reducing right or left skewness.
# - **Non-Normal Distributions:** Many ML models perform better with normally distributed data.
# - **Heteroscedasticity:** Stabilizes variance in regression models.
# - **Outliers:** Reduces the impact of extreme values.
#
# ---
#
# ## 🧮 **Mathematical Explanation:**
#
# ### 🔸 **Log Transformation:**
# Reduces right skewness by compressing large values.
# $$
# X' = \log(X + c)
# $$
# *(Add a constant \( c \) if \( X \) contains zero or negative values)*
#
# ### 🔸 **Square Root Transformation:**
# Reduces moderate right skewness.
# $$
# X' = \sqrt{X}
# $$
#
# ### 🔸 **Box-Cox Transformation:**
# A flexible method that includes log and power transforms.
# $$
# X' = \frac{X^\lambda - 1}{\lambda}, \text{ if } \lambda \neq 0
# $$
# $$
# X' = \log(X), \text{ if } \lambda = 0
# $$
#
# ---
#
# ## 🛠️ **Code Example: Log & Box-Cox Transformations**
#
# ```python
# import pandas as pd
# import numpy as np
# from scipy import stats
# import matplotlib.pyplot as plt
#
# # Sample Data (Skewed)
# data = pd.DataFrame({'Sales': [100, 200, 500, 3000, 150, 6000, 400]})
#
# # Log Transformation
# data['Sales_log'] = np.log1p(data['Sales'])
#
# # Box-Cox Transformation (Requires positive data)
# data['Sales_boxcox'], fitted_lambda = stats.boxcox(data['Sales'])
#
# # Plot Distributions
# fig, axes = plt.subplots(1, 3, figsize=(15, 4))
# axes[0].hist(data['Sales'], bins=20, color='skyblue')
# axes[0].set_title('Original Distribution')
#
# axes[1].hist(data['Sales_log'], bins=20, color='lightgreen')
# axes[1].set_title('Log Transformed')
#
# axes[2].hist(data['Sales_boxcox'], bins=20, color='salmon')
# axes[2].set_title('Box-Cox Transformed')
#
# plt.show()

# %% [markdown]
# # 📊 **12.Data Aggregation & Grouping**
#
# ## 📖 **Definition:**
# Data aggregation involves summarizing large datasets to extract meaningful insights. **Grouping** organizes data into subsets based on specific features, enabling targeted analysis.
#
# ---
#
# ## 💡 **Use Cases:**
# - **Sales Analytics:** Total sales by region, product, or time period.
# - **Customer Insights:** Average purchase value per customer.
# - **Financial Reporting:** Summarizing revenues and expenses.
# - **Time Series Analysis:** Monthly or yearly data trends.
# - **Performance Tracking:** Analyzing KPIs by departments or teams.
#
# ---
#
# ## 🛠️ **Methods:**
#
# ### 🔸 **1. GroupBy (Pandas):**
# Groups data by specific columns and applies aggregation functions (e.g., sum, mean).
#
# ```python
# import pandas as pd
#
# # Sample Data
# df = pd.DataFrame({
#     'Product': ['A', 'B', 'A', 'C', 'B', 'C', 'A'],
#     'Region': ['East', 'West', 'East', 'West', 'East', 'West', 'East'],
#     'Sales': [200, 300, 250, 400, 350, 500, 150]
# })
#
# # Group by Product and Aggregate Sales
# grouped = df.groupby('Product')['Sales'].sum().reset_index()
# print(grouped)

# %%
import pandas as pd

# Sample Data
df = pd.DataFrame({
    'Product': ['A', 'B', 'A', 'C', 'B', 'C', 'A'],
    'Region': ['East', 'West', 'East', 'West', 'East', 'West', 'East'],
    'Sales': [200, 300, 250, 400, 350, 500, 150]
})

# Group by Product and Aggregate Sales
grouped = df.groupby('Product')['Sales'].sum().reset_index()
print(grouped)
# Out:
#   Product  Sales
# 0       A    600
# 1       B    650
# 2       C    900

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('medical_students_dataset.csv')

# Group by 'Blood Type' and calculate average 'Cholesterol'
grouped = df.groupby('Blood Type')['Cholesterol'].mean().reset_index()

# Rename columns for clarity
grouped.columns = ['Blood Type', 'Average Cholesterol']

# Display result
print(grouped)
# Out:
#   Blood Type  Average Cholesterol
# 0          A           184.241681
# 1         AB           184.222711
# 2          B           184.831119
# 3          O           184.617990

# %% [markdown]
# ### 🔸 **2. Pivot Tables:**
# Creates multi-dimensional summaries, useful for cross-tabulation.

# %%
import pandas as pd

# Sample Data
df = pd.DataFrame({
    'Product': ['A', 'B', 'A', 'C', 'B', 'C', 'A'],
    'Region': ['East', 'West', 'East', 'West', 'East', 'West', 'East'],
    'Sales': [200, 300, 250, 400, 350, 500, 150]
})

# Create Pivot Table: Sales by Product and Region
pivot = pd.pivot_table(df, values='Sales', index='Product', columns='Region', aggfunc='sum', fill_value=0)
print(pivot)
# Out:
# Region   East  West
# Product
# A         600     0
# B         350   300
# C           0   900

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('medical_students_dataset.csv')

# Create Pivot Table: Average Cholesterol by Gender and Blood Type
pivot = pd.pivot_table(df,
                       values='Cholesterol',
                       index='Gender',
                       columns='Blood Type',
                       aggfunc='mean',
                       fill_value=0)

# Display result
print(pivot)
# Out:
# Blood Type           A          AB           B           O
# Gender
# Female      184.373947  184.124586  185.097742  184.639234
# Male        184.273301  184.407743  184.758665  184.619087

# %% [markdown]
# # <center><font color='#2A9D8F'>📊 Joining Tables</font></center>
#
# ## 🔗 **Table Joins: Combine Multiple Datasets Efficiently**
#
# Joining tables allows you to merge datasets based on common keys, enabling deeper insights and more complex analysis.
#
# ---
#
# ### 📁 **1. Horizontal Joins (Merge by Rows)**
# - **Definition:** Combine tables **side-by-side** by matching rows using a common key (similar to SQL joins).
# - **Types of Joins:**
#   - **Inner Join:** Returns rows with matching keys in both tables.
#   - **Left Join:** Returns all rows from the left table and matching rows from the right.
#   - **Right Join:** Returns all rows from the right table and matching rows from the left.
#   - **Outer Join:** Returns all rows from both tables, filling non-matching values with `NaN`.
#
# ```python
# import pandas as pd
#
# # Sample DataFrames
# df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']})
# df2 = pd.DataFrame({'ID': [2, 3, 4], 'Score': [85, 90, 95]})
#
# # Inner Join
# merged_df = pd.merge(df1, df2, on='ID', how='inner')
# print(merged_df)

# %%
import pandas as pd

# Sample DataFrames
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Score': [85, 90, 95]})

# Inner Join
merged_df = pd.merge(df1, df2, on='ID', how='inner')
print(merged_df)

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('medical_students_dataset.csv')

# Example: Split the dataset into two DataFrames
df1 = df[['Student ID', 'Gender', 'Age', 'Blood Type']]
df2 = df[['Student ID', 'Cholesterol', 'Diabetes', 'BMI']]

# Inner Join on 'Student ID'
merged_df = pd.merge(df1, df2, on='Student ID', how='inner')

# Display the merged DataFrame
print(merged_df)

# %% [markdown]
# # 📊 **2. Vertical Joins (Concatenation by Columns)**
#
# ### ✅ **Definition:**
# Stack tables **on top of each other**, combining rows while maintaining the same columns.
#
# ### 📌 **Use Case:**
# Ideal for merging datasets with a similar structure, such as **monthly sales reports** or **survey results** from different periods.
#
# ---
#
# ### 💻 **Python Example:**
#
# ```python
# import pandas as pd
#
# # Sample DataFrames
# df3 = pd.DataFrame({'ID': [1, 2], 'Sales': [300, 400]})
# df4 = pd.DataFrame({'ID': [3, 4], 'Sales': [500, 600]})
#
# # Vertical Concatenation
# concat_df = pd.concat([df3, df4], ignore_index=True)
# print(concat_df)

# %%
import pandas as pd

# Sample DataFrames
df3 = pd.DataFrame({'ID': [1, 2], 'Sales': [300, 400]})
df4 = pd.DataFrame({'ID': [3, 4], 'Sales': [500, 600]})

# Vertical Concatenation
concat_df = pd.concat([df3, df4], ignore_index=True)
print(concat_df)

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('medical_students_dataset.csv')

# Split into two DataFrames (Example: based on index)
df1 = df.iloc[:50000]   # First 50,000 rows
df2 = df.iloc[50000:100000]  # Next 50,000 rows

# Vertical Concatenation
concat_df = pd.concat([df1, df2], ignore_index=True)

# Display the concatenated DataFrame
print(concat_df)
# Out:
#        Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0             1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1             2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2             3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3             NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4             5.0  23.0  Female         NaN  46.234173          O        NaN
# ...           ...   ...     ...         ...        ...        ...        ...
# 99995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 99996         NaN  29.0  Female  163.917675  45.225194          O  16.831734
# 99997     99998.0  34.0     NaN  173.275523  99.648914          B  33.189303
# 99998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 99999    100000.0  20.0  Female  153.927409  99.928405        NaN  42.175189
#
# ...

# %% [markdown]
# # <center><font color='#2A9D8F'>📊 13.Summary & Best Practices</font></center>
#
# ## ✅ **Recap of Key Concepts:**
# - **Feature Scaling:** Normalize or standardize features to improve model performance.
# - **Encoding Categorical Variables:** Use One-Hot, Label, or Target Encoding based on data type.
# - **Feature Extraction:** Apply methods like **PCA** for dimensionality reduction and **TF-IDF/Word Embeddings** for text data.
# - **Feature Selection:** Use **Filter**, **Wrapper**, and **Embedded** methods to retain the most relevant features.
# - **Log & Power Transformations:** Correct skewed data and improve model assumptions.
# - **Data Aggregation & Grouping:** Summarize large datasets using **Groupby** and **Pivot Tables**.
#
# ---
#
# ## 🌟 **Best Practices in Data Wrangling:**
# - **Handle Missing Data:** Use imputation or removal based on context.
# - **Scale & Encode Before Modeling:** Ensure consistency across all features.
# - **Detect & Handle Outliers:** Use statistical methods (e.g., IQR, Z-score).
# - **Choose the Right Transformation:** Apply log, square root, or Box-Cox transformations based on data distribution.
# - **Document Each Step:** Maintain reproducibility and clarity in the data pipeline.
#
# ---
#
# ## 🛠️ **Tools & Libraries to Use:**
# - **Pandas** → Data manipulation & aggregation
# - **NumPy** → Numerical operations
# - **Scikit-learn** → Preprocessing, feature scaling, selection, and modeling
# - **Gensim** → Word2Vec and other word embeddings
# - **Matplotlib/Seaborn** → Data visualization
# - **Category Encoders** → Advanced encoding techniques
#
# ---
#
# ## 🌍 **Real-World Applications:**
# - **E-commerce:** Customer segmentation, price prediction, recommendation engines
# - **Healthcare:** Patient risk analysis, medical image classification
# - **Finance:** Fraud detection, stock price forecasting
# - **Marketing:** Customer lifetime value prediction, sentiment analysis
#
# ---
#
# <center><font color='#2A9D8F'>💡 Mastering Data Wrangling ensures cleaner data, better models, and deeper insights!</font></center>

# %%
#join tables horizontal - vertical
# dataset
